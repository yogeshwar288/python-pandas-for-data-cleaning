# %% [markdown]
# # python panda tutorial-5

# %% [markdown]
# # how to write CSV file

# %%
import pandas as pd

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df1
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# 7   Farm expenses price index, Sheep, beef, and gr...     1199
# ...

# %%
df11=pd.read_csv('E:\csv files\student_result1.csv')
df11
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %%
df11=pd.read_csv('E:\csv files\student_result1.csv',header=1)
df11
# Out:
#    1001  A  10  2  3  50
# 0  1002  B  10  6  2  80
# 1  1003  A  10  3  2  60
# 2  1004  C  11  0  1  45
# 3  1005  C  12  5  2  75

# %%
df11=pd.read_csv('E:\csv files\student_result1.csv',header=None)
df11
# Out:
#             0        1      2          3                       4           5
# 0  Student ID  Section  Class  Study hrs  Social Media usage hrs  Percentage
# 1        1001        A     10          2                       3          50
# 2        1002        B     10          6                       2          80
# 3        1003        A     10          3                       2          60
# 4        1004        C     11          0                       1          45
# 5        1005        C     12          5                       2          75

# %%
df11=pd.read_csv('E:\csv files\student_result1.csv',header=None,prefix='column')
df11
# Out:
#       column0  column1 column2    column3                 column4     column5
# 0  Student ID  Section   Class  Study hrs  Social Media usage hrs  Percentage
# 1        1001        A      10          2                       3          50
# 2        1002        B      10          6                       2          80
# 3        1003        A      10          3                       2          60
# 4        1004        C      11          0                       1          45
# 5        1005        C      12          5                       2          75

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df1
# Out:
#                    0        1  \
# 0   Series reference   Period
# 1         FPIQ.SEA31  2019.09
# 2         FPIQ.SEA31  2019.12
# 3         FPIQ.SEA31  2020.03
# 4         FPIQ.SEB31  2019.09
# 5         FPIQ.SEB31  2019.12
# 6         FPIQ.SEB31  2020.03
# 7         FPIQ.SEB39  2019.09
# 8         FPIQ.SEB39  2019.12
# 9         FPIQ.SEB39  2020.03
# 10        FPIQ.SEB99  2019.12
# 11        FPIQ.SEC31  2019.09
#
#                                                     2        3  \
# 0                                         Description  Revised
# 1   Farm expenses price index, Horticulture and fr...     1434
# 2   Farm expenses price index, Horticulture and fr...     1453
# 3   Farm expenses price index, Horticulture and fr...     1412
# 4   Farm expenses price index, Sheep, beef, and gr...     1489
# 5   Farm expenses price index, Sheep, beef, and gr...     1507
# 6   Farm expenses price index, Sheep, beef, and gr...     1462
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',header=1)
df1
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# 7   Farm expenses price index, Sheep, beef, and gr...     1199
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',header=None)
df1
# Out:
#                    0        1  \
# 0                  0        1
# 1   Series reference   Period
# 2         FPIQ.SEA31  2019.09
# 3         FPIQ.SEA31  2019.12
# 4         FPIQ.SEA31  2020.03
# 5         FPIQ.SEB31  2019.09
# 6         FPIQ.SEB31  2019.12
# 7         FPIQ.SEB31  2020.03
# 8         FPIQ.SEB39  2019.09
# 9         FPIQ.SEB39  2019.12
# 10        FPIQ.SEB39  2020.03
# 11        FPIQ.SEB99  2019.12
# 12        FPIQ.SEC31  2019.09
#
#                                                     2        3  \
# 0                                                   2        3
# 1                                         Description  Revised
# 2   Farm expenses price index, Horticulture and fr...     1434
# 3   Farm expenses price index, Horticulture and fr...     1453
# 4   Farm expenses price index, Horticulture and fr...     1412
# 5   Farm expenses price index, Sheep, beef, and gr...     1489
# 6   Farm expenses price index, Sheep, beef, and gr...     1507
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',header=None,prefix='columns')
df1
# Out:
#             columns0 columns1  \
# 0                  0        1
# 1   Series reference   Period
# 2         FPIQ.SEA31  2019.09
# 3         FPIQ.SEA31  2019.12
# 4         FPIQ.SEA31  2020.03
# 5         FPIQ.SEB31  2019.09
# 6         FPIQ.SEB31  2019.12
# 7         FPIQ.SEB31  2020.03
# 8         FPIQ.SEB39  2019.09
# 9         FPIQ.SEB39  2019.12
# 10        FPIQ.SEB39  2020.03
# 11        FPIQ.SEB99  2019.12
# 12        FPIQ.SEC31  2019.09
#
#                                              columns2 columns3  \
# 0                                                   2        3
# 1                                         Description  Revised
# 2   Farm expenses price index, Horticulture and fr...     1434
# 3   Farm expenses price index, Horticulture and fr...     1453
# 4   Farm expenses price index, Horticulture and fr...     1412
# 5   Farm expenses price index, Sheep, beef, and gr...     1489
# 6   Farm expenses price index, Sheep, beef, and gr...     1507
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',header=None,prefix='columns data')
df1
# Out:
#        columns data0 columns data1  \
# 0                  0             1
# 1   Series reference        Period
# 2         FPIQ.SEA31       2019.09
# 3         FPIQ.SEA31       2019.12
# 4         FPIQ.SEA31       2020.03
# 5         FPIQ.SEB31       2019.09
# 6         FPIQ.SEB31       2019.12
# 7         FPIQ.SEB31       2020.03
# 8         FPIQ.SEB39       2019.09
# 9         FPIQ.SEB39       2019.12
# 10        FPIQ.SEB39       2020.03
# 11        FPIQ.SEB99       2019.12
# 12        FPIQ.SEC31       2019.09
#
#                                         columns data2 columns data3  \
# 0                                                   2             3
# 1                                         Description       Revised
# 2   Farm expenses price index, Horticulture and fr...          1434
# 3   Farm expenses price index, Horticulture and fr...          1453
# 4   Farm expenses price index, Horticulture and fr...          1412
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',header=None,prefix=' data columns')
df1
# Out:
#        data columns0  data columns1  \
# 0                  0              1
# 1   Series reference         Period
# 2         FPIQ.SEA31        2019.09
# 3         FPIQ.SEA31        2019.12
# 4         FPIQ.SEA31        2020.03
# 5         FPIQ.SEB31        2019.09
# 6         FPIQ.SEB31        2019.12
# 7         FPIQ.SEB31        2020.03
# 8         FPIQ.SEB39        2019.09
# 9         FPIQ.SEB39        2019.12
# 10        FPIQ.SEB39        2020.03
# 11        FPIQ.SEB99        2019.12
# 12        FPIQ.SEC31        2019.09
#
#                                         data columns2  data columns3  \
# 0                                                   2              3
# 1                                         Description        Revised
# 2   Farm expenses price index, Horticulture and fr...           1434
# 3   Farm expenses price index, Horticulture and fr...           1453
# 4   Farm expenses price index, Horticulture and fr...           1412
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',names=['series','time','descrip','revised nu.','published'])
df1
# Out:
#               series     time  \
# 0                  0        1
# 1   Series reference   Period
# 2         FPIQ.SEA31  2019.09
# 3         FPIQ.SEA31  2019.12
# 4         FPIQ.SEA31  2020.03
# 5         FPIQ.SEB31  2019.09
# 6         FPIQ.SEB31  2019.12
# 7         FPIQ.SEB31  2020.03
# 8         FPIQ.SEB39  2019.09
# 9         FPIQ.SEB39  2019.12
# 10        FPIQ.SEB39  2020.03
# 11        FPIQ.SEB99  2019.12
# 12        FPIQ.SEC31  2019.09
#
#                                               descrip revised nu.  \
# 0                                                   2           3
# 1                                         Description     Revised
# 2   Farm expenses price index, Horticulture and fr...        1434
# 3   Farm expenses price index, Horticulture and fr...        1453
# 4   Farm expenses price index, Horticulture and fr...        1412
# 5   Farm expenses price index, Sheep, beef, and gr...        1489
# 6   Farm expenses price index, Sheep, beef, and gr...        1507
# ...

# %%
df11=pd.read_csv('E:\csv files\student_result1.csv',header=None,names=['first column','2nd column','3rd column','4th column','5th column','6th column',])
df11
# Out:
#   first column 2nd column 3rd column 4th column              5th column  \
# 0   Student ID    Section      Class  Study hrs  Social Media usage hrs
# 1         1001          A         10          2                       3
# 2         1002          B         10          6                       2
# 3         1003          A         10          3                       2
# 4         1004          C         11          0                       1
# 5         1005          C         12          5                       2
#
#    6th column
# 0  Percentage
# 1          50
# 2          80
# 3          60
# 4          45
# 5          75

# %%
df11
# Out:
#   first column 2nd column 3rd column 4th column              5th column  \
# 0   Student ID    Section      Class  Study hrs  Social Media usage hrs
# 1         1001          A         10          2                       3
# 2         1002          B         10          6                       2
# 3         1003          A         10          3                       2
# 4         1004          C         11          0                       1
# 5         1005          C         12          5                       2
#
#    6th column
# 0  Percentage
# 1          50
# 2          80
# 3          60
# 4          45
# 5          75
