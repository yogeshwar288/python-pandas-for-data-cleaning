# %% [markdown]
# # python pandas Tutorial-10

# %% [markdown]
# # handling missing value

# %%
#fillna()

# %% [markdown]
# # pandas fillna()

# %%
import pandas as pd

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(55)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                 55
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                 55
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization    0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances   0.58
# ...

# %%
df11.fillna({'Muhammed MacIntyre':'Carlos Soltero','Nunavut':'Nunavut','0.8':'0.50'})
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380     Carlos Soltero
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(method='ffill')
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(method='bfill')
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380     Carlos Soltero
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs       Carl Jackson
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(method='ffill',axis=0)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(method='ffill',axis=1)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl
# 2   4                                               R380
# 3   5                           Holmes HEPA Air Purifier
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 5   7  Angle-D Binders with Locking Rings, Label Holders
# 6   8            SAFCO Mobile Desk Side File, Wire Frame
# 7   9              SAFCO Commercial Wire Shelving, Black
# 8  10                                          Xerox 198
#
#                                   Muhammed MacIntyre    3  -213.25   38.94  \
# 0                                       Barry French  293   457.81  208.16
# 1                                       Barry French  293    46.71    8.69
# 2                                               R380  483  1198.97  195.99
# 3                                     Carlos Soltero  515    30.94   21.78
# ...

# %%
df11.fillna(method='bfill',axis=0)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380     Carlos Soltero
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs       Carl Jackson
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(method='bfill',axis=1)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                483
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                515
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35                         Nunavut  \
# 0  293   457.81  208.16  68.02                         Nunavut
# 1  293    46.71    8.69   2.99                         Nunavut
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv')
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df.fillna(0)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                0  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      0.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(2)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                2  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      2.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna({'Revised':1400})
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(2)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                2  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      2.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna({'Series reference':'apple','Revised':1400,'Initially published':1405.0})
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6            apple  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1400.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method='ffill')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6       FPIQ.SEB31  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method='pad')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6       FPIQ.SEB31  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method='bfill')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6       FPIQ.SEB39  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method="ffill",axis=0)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6       FPIQ.SEB31  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method="ffill",axis=1)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  \
# 0  Farm expenses price index, Horticulture and fr...
# 1  Farm expenses price index, Horticulture and fr...
# 2  Farm expenses price index, Horticulture and fr...
# 3  Farm expenses price index, Sheep, beef, and gr...
# 4  Farm expenses price index, Sheep, beef, and gr...
# 5  Farm expenses price index, Sheep, beef, and gr...
# 6  Farm expenses price index, Sheep, beef, and gr...
# 7  Farm expenses price index, Sheep, beef, and gr...
# 8  Farm expenses price index, Sheep, beef, and gr...
# 9  Farm expenses price index, Sheep, beef, and gr...
#
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method="bfill",axis=1)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6          2019.09  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description Revised  \
# 0  Farm expenses price index, Horticulture and fr...    1434
# 1  Farm expenses price index, Horticulture and fr...    1453
# 2  Farm expenses price index, Horticulture and fr...    1412
# 3  Farm expenses price index, Sheep, beef, and gr...    1489
# 4  Farm expenses price index, Sheep, beef, and gr...    1507
# 5  Farm expenses price index, Sheep, beef, and gr...    1465
# 6  Farm expenses price index, Sheep, beef, and gr...    1193
# 7  Farm expenses price index, Sheep, beef, and gr...    1199
# 8  Farm expenses price index, Sheep, beef, and gr...    1187
# ...

# %%
df.fillna(0,limit=(1))
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                0  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      0.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(0,limit=1)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                0  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      0.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(0,limit=2)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                0  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      0.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(method='ffill',limit=1)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6       FPIQ.SEB31  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.fillna(4,inplace=True)
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6                4  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      4.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna({'Muhammed MacIntyre':'Carlos Soltero','Nunavut':'Nunavut','0.8':'0.50'},limit=1)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380     Carlos Soltero
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(method='ffill',limit=1,axis=0)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.fillna(0,inplace=True)
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380               fill
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs               fill
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380               fill
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs               fill
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...
