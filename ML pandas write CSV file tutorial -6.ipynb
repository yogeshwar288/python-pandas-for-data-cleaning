# %% [markdown]
# # python panda tutorial-6

# %% [markdown]
# # how to write csv file

# %%
import pandas as pd
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#                    0        1  \
# 0   Series reference   Period
# 1         FPIQ.SEA31  2019.09
# 2         FPIQ.SEA31  2019.12
# 3         FPIQ.SEA31  2020.03
# 4         FPIQ.SEB31  2019.09
# 5         FPIQ.SEB31  2019.12
# 6         FPIQ.SEB31  2020.03
# 7         FPIQ.SEB39  2019.09
# 8         FPIQ.SEB39  2019.12
# 9         FPIQ.SEB39  2020.03
# 10        FPIQ.SEB99  2019.12
# 11        FPIQ.SEC31  2019.09
#
#                                                     2        3  \
# 0                                         Description  Revised
# 1   Farm expenses price index, Horticulture and fr...     1434
# 2   Farm expenses price index, Horticulture and fr...     1453
# 3   Farm expenses price index, Horticulture and fr...     1412
# 4   Farm expenses price index, Sheep, beef, and gr...     1489
# 5   Farm expenses price index, Sheep, beef, and gr...     1507
# 6   Farm expenses price index, Sheep, beef, and gr...     1462
# ...

# %%
df.head()
# Out:
#                   0        1  \
# 0  Series reference   Period
# 1        FPIQ.SEA31  2019.09
# 2        FPIQ.SEA31  2019.12
# 3        FPIQ.SEA31  2020.03
# 4        FPIQ.SEB31  2019.09
#
#                                                    2        3  \
# 0                                        Description  Revised
# 1  Farm expenses price index, Horticulture and fr...     1434
# 2  Farm expenses price index, Horticulture and fr...     1453
# 3  Farm expenses price index, Horticulture and fr...     1412
# 4  Farm expenses price index, Sheep, beef, and gr...     1489
#
#                      4
# 0  Initially published
# 1                 1453
# 2                 1472
# 3                 1431
# 4                 1492

# %%
df.head(1)
# Out:
#                   0       1            2        3                    4
# 0  Series reference  Period  Description  Revised  Initially published

# %%
df.head(8)
# Out:
#                   0        1  \
# 0  Series reference   Period
# 1        FPIQ.SEA31  2019.09
# 2        FPIQ.SEA31  2019.12
# 3        FPIQ.SEA31  2020.03
# 4        FPIQ.SEB31  2019.09
# 5        FPIQ.SEB31  2019.12
# 6        FPIQ.SEB31  2020.03
# 7        FPIQ.SEB39  2019.09
#
#                                                    2        3  \
# 0                                        Description  Revised
# 1  Farm expenses price index, Horticulture and fr...     1434
# 2  Farm expenses price index, Horticulture and fr...     1453
# 3  Farm expenses price index, Horticulture and fr...     1412
# 4  Farm expenses price index, Sheep, beef, and gr...     1489
# 5  Farm expenses price index, Sheep, beef, and gr...     1507
# 6  Farm expenses price index, Sheep, beef, and gr...     1462
# 7  Farm expenses price index, Sheep, beef, and gr...     1193
#
#                      4
# 0  Initially published
# 1                 1453
# 2                 1472
# 3                 1431
# ...

# %%
df.tail()
# Out:
#              0        1                                                  2  \
# 7   FPIQ.SEB39  2019.09  Farm expenses price index, Sheep, beef, and gr...
# 8   FPIQ.SEB39  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 9   FPIQ.SEB39  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 10  FPIQ.SEB99  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 11  FPIQ.SEC31  2019.09  Farm expenses price index, Dairy farms, Livest...
#
#        3     4
# 7   1193  1194
# 8   1199  1200
# 9   1187  1188
# 10  1159  1160
# 11   992  1074

# %%
df.tail(2)
# Out:
#              0        1                                                  2  \
# 10  FPIQ.SEB99  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 11  FPIQ.SEC31  2019.09  Farm expenses price index, Dairy farms, Livest...
#
#        3     4
# 10  1159  1160
# 11   992  1074

# %%
df.tail(7)
# Out:
#              0        1                                                  2  \
# 5   FPIQ.SEB31  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 6   FPIQ.SEB31  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 7   FPIQ.SEB39  2019.09  Farm expenses price index, Sheep, beef, and gr...
# 8   FPIQ.SEB39  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 9   FPIQ.SEB39  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 10  FPIQ.SEB99  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 11  FPIQ.SEC31  2019.09  Farm expenses price index, Dairy farms, Livest...
#
#        3     4
# 5   1507  1510
# 6   1462  1465
# 7   1193  1194
# 8   1199  1200
# 9   1187  1188
# 10  1159  1160
# 11   992  1074

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',dtype={'Revised': 'float64'})
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...   1434.0
# 1   Farm expenses price index, Horticulture and fr...   1453.0
# 2   Farm expenses price index, Horticulture and fr...   1412.0
# 3   Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4   Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5   Farm expenses price index, Sheep, beef, and gr...   1462.0
# 6   Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7   Farm expenses price index, Sheep, beef, and gr...   1199.0
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',dtype={'Revised': 'float64','Initially published':'float64'})
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...   1434.0
# 1   Farm expenses price index, Horticulture and fr...   1453.0
# 2   Farm expenses price index, Horticulture and fr...   1412.0
# 3   Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4   Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5   Farm expenses price index, Sheep, beef, and gr...   1462.0
# 6   Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7   Farm expenses price index, Sheep, beef, and gr...   1199.0
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# 7   Farm expenses price index, Sheep, beef, and gr...     1199
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv', true_values=['yes'])
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# 7   Farm expenses price index, Sheep, beef, and gr...     1199
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# 7   Farm expenses price index, Sheep, beef, and gr...     1199
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv',true_values=['yes'],false_values=['no'])
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# 7   Farm expenses price index, Sheep, beef, and gr...     1199
# ...
