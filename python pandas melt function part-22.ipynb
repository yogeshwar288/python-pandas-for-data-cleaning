# %%
import pandas as pd

# %%
df=pd.read_csv('E:\\csv files\\itttttttt.csv')

# %%
df
# Out:
#               Name             Industry  Inception           Expenses  \
# 0          Lamtone          IT Services       2009  6,482,465 Dollars
# 1        Stripfind   Financial Services       2010    916,455 Dollars
# 2  Canecorporation               Health       2012  7,591,189 Dollars
# 3         Mattouch          IT Services       2013  7,429,377 Dollars
# 4        Techdrill               Health       2009  7,435,363 Dollars
# 5         Techline               Health       2006  5,470,303 Dollars
# 6          Cityace               Health       2010  6,249,498 Dollars
# 7   Kayelectronics               Health       2009  3,878,113 Dollars
# 8          Ganzlax          IT Services       2011  3,878,113 Dollars
# 9      Trantraxlax  Government Services       2011  5,635,276 Dollars
#
#      Profit Growth
# 0   5274553    30%
# 1  11412916    20%
# 2   3005820     7%
# 3   6597557     7%
# 4   3138627     7%
# 5   8427816     7%
# 6   3005116    16%
# 7   5573830     4%
# ...

# %%
pd.melt(df)
# Out:
#      variable                value
# 0        Name              Lamtone
# 1        Name            Stripfind
# 2        Name      Canecorporation
# 3        Name             Mattouch
# 4        Name            Techdrill
# 5        Name             Techline
# 6        Name              Cityace
# 7        Name       Kayelectronics
# 8        Name              Ganzlax
# 9        Name          Trantraxlax
# 10   Industry          IT Services
# 11   Industry   Financial Services
# 12   Industry               Health
# 13   Industry          IT Services
# 14   Industry               Health
# 15   Industry               Health
# 16   Industry               Health
# 17   Industry               Health
# 18   Industry          IT Services
# 19   Industry  Government Services
# 20  Inception                 2009
# 21  Inception                 2010
# 22  Inception                 2012
# 23  Inception                 2013
# 24  Inception                 2009
# 25  Inception                 2006
# ...

# %%
pd.melt(df,id_vars=['Name'])
# Out:
#                Name   variable                value
# 0           Lamtone   Industry          IT Services
# 1         Stripfind   Industry   Financial Services
# 2   Canecorporation   Industry               Health
# 3          Mattouch   Industry          IT Services
# 4         Techdrill   Industry               Health
# 5          Techline   Industry               Health
# 6           Cityace   Industry               Health
# 7    Kayelectronics   Industry               Health
# 8           Ganzlax   Industry          IT Services
# 9       Trantraxlax   Industry  Government Services
# 10          Lamtone  Inception                 2009
# 11        Stripfind  Inception                 2010
# 12  Canecorporation  Inception                 2012
# 13         Mattouch  Inception                 2013
# 14        Techdrill  Inception                 2009
# 15         Techline  Inception                 2006
# 16          Cityace  Inception                 2010
# ...

# %%
pd.melt(df,id_vars=['Inception','Industry','Growth','Expenses','Profit'])
# Out:
#    Inception             Industry Growth           Expenses    Profit  \
# 0       2009          IT Services    30%  6,482,465 Dollars   5274553
# 1       2010   Financial Services    20%    916,455 Dollars  11412916
# 2       2012               Health     7%  7,591,189 Dollars   3005820
# 3       2013          IT Services     7%  7,429,377 Dollars   6597557
# 4       2009               Health     7%  7,435,363 Dollars   3138627
# 5       2006               Health     7%  5,470,303 Dollars   8427816
# 6       2010               Health    16%  6,249,498 Dollars   3005116
# 7       2009               Health     4%  3,878,113 Dollars   5573830
# 8       2011          IT Services    18%  3,878,113 Dollars  11901180
# 9       2011  Government Services     7%  5,635,276 Dollars   5453060
#
#   variable            value
# 0     Name          Lamtone
# 1     Name        Stripfind
# 2     Name  Canecorporation
# 3     Name         Mattouch
# 4     Name        Techdrill
# ...

# %%
pd.melt(df,id_vars=['Industry'],value_vars=['Growth'])
# Out:
#               Industry variable value
# 0          IT Services   Growth   30%
# 1   Financial Services   Growth   20%
# 2               Health   Growth    7%
# 3          IT Services   Growth    7%
# 4               Health   Growth    7%
# 5               Health   Growth    7%
# 6               Health   Growth   16%
# 7               Health   Growth    4%
# 8          IT Services   Growth   18%
# 9  Government Services   Growth    7%

# %%
pd.melt(df,id_vars=['Name'],value_vars=['Growth'],value_name='growth rate')
# Out:
#               Name variable growth catagry
# 0          Lamtone   Growth            30%
# 1        Stripfind   Growth            20%
# 2  Canecorporation   Growth             7%
# 3         Mattouch   Growth             7%
# 4        Techdrill   Growth             7%
# 5         Techline   Growth             7%
# 6          Cityace   Growth            16%
# 7   Kayelectronics   Growth             4%
# 8          Ganzlax   Growth            18%
# 9      Trantraxlax   Growth             7%

# %%
pd.melt(df,id_vars=['Name'],value_vars=['Growth'],var_name=['growth catagory'],value_name='growth name')
# Out:
#               Name growth catagory growth name
# 0          Lamtone          Growth         30%
# 1        Stripfind          Growth         20%
# 2  Canecorporation          Growth          7%
# 3         Mattouch          Growth          7%
# 4        Techdrill          Growth          7%
# 5         Techline          Growth          7%
# 6          Cityace          Growth         16%
# 7   Kayelectronics          Growth          4%
# 8          Ganzlax          Growth         18%
# 9      Trantraxlax          Growth          7%
