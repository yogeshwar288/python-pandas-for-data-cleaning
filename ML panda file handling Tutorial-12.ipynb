# %% [markdown]
# # Python pandas Tutorial-12

# %% [markdown]
# # Pandas interpolate()

# %%
import pandas as pd

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Period')
df1
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df11=pd.read_csv('E:\\csv files\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics (1).csv',nrows=10)
df11
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6       FPIQ.SEB39  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     1462
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df11=pd.read_csv('E:\\csv files\\ppppppppppppppppp.csv',parse_dates=['Period'],index_col='Period')
df11
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...   1434.0
# 2020-10-02  Farm expenses price index, Horticulture and fr...   1453.0
# 2020-11-03  Farm expenses price index, Horticulture and fr...   1412.0
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 2020-05-13                                                NaN   1507.0
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...      NaN
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 2020-12-08                                                NaN   1199.0
# ...

# %%
df11.interpolate()
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1350.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df11.interpolate(method='time')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description      Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...  1434.000000
# 2020-10-02  Farm expenses price index, Horticulture and fr...  1453.000000
# 2020-11-03  Farm expenses price index, Horticulture and fr...  1412.000000
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...  1489.000000
# 2020-05-13                                                NaN  1507.000000
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...  1347.507937
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...  1193.000000
# ...

# %%
df.interpolate()
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df.interpolate(method='time')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-46c3e76abc7e> in <module>
# ----> 1 df11.interpolate(method='time')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7220                 "those NaNs before interpolating."
#    7221             )
# -> 7222         new_data = obj._mgr.interpolate(
#    7223             method=method,
#    7224             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     591
#     592     def interpolate(self, **kwargs) -> "BlockManager":
# --> 593         return self.apply("interpolate", **kwargs)
#     594
#     595     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ...

# %%
type(df.Period[1])
# Out:
# numpy.float64

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'])
df
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31 2019-09-01
# 1       FPIQ.SEA31 2019-12-01
# 2       FPIQ.SEA31 2020-03-01
# 3       FPIQ.SEB31 2019-09-01
# 4       FPIQ.SEB31 2019-12-01
# 5       FPIQ.SEB31 2020-03-01
# 6              NaN 2019-09-01
# 7       FPIQ.SEB39 2019-12-01
# 8       FPIQ.SEB39 2020-03-01
# 9       FPIQ.SEB99 2019-12-01
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
type(df.Period)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-da92e654536c> in <module>
# ----> 1 type(df.Period)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Period'

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Revised')
df
# Out:
#         Series reference     Period  \
# Revised
# 1434          FPIQ.SEA31 2019-09-01
# 1453          FPIQ.SEA31 2019-12-01
# 1412          FPIQ.SEA31 2020-03-01
# 1489          FPIQ.SEB31 2019-09-01
# 1507          FPIQ.SEB31 2019-12-01
# 4500          FPIQ.SEB31 2020-03-01
# 1193                 NaN 2019-09-01
# 1199          FPIQ.SEB39 2019-12-01
# 1187          FPIQ.SEB39 2020-03-01
# 1159          FPIQ.SEB99 2019-12-01
#
#                                                Description  \
# Revised
# 1434     Farm expenses price index, Horticulture and fr...
# 1453     Farm expenses price index, Horticulture and fr...
# 1412     Farm expenses price index, Horticulture and fr...
# 1489     Farm expenses price index, Sheep, beef, and gr...
# 1507     Farm expenses price index, Sheep, beef, and gr...
# 4500     Farm expenses price index, Sheep, beef, and gr...
# 1193     Farm expenses price index, Sheep, beef, and gr...
# 1199     Farm expenses price index, Sheep, beef, and gr...
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Period')
df
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df.interpolate(method="time")
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df.interpolate(method='index')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df11.interpolate(method='index')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description      Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...  1434.000000
# 2020-10-02  Farm expenses price index, Horticulture and fr...  1453.000000
# 2020-11-03  Farm expenses price index, Horticulture and fr...  1412.000000
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...  1489.000000
# 2020-05-13                                                NaN  1507.000000
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...  1347.507937
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...  1193.000000
# ...

# %%
df11=pd.read_csv('E:\\csv files\\ppppppppppppppppp.csv',parse_dates=['Period'],index_col='Period')
df11
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...   1434.0
# 2020-10-02  Farm expenses price index, Horticulture and fr...   1453.0
# 2020-11-03  Farm expenses price index, Horticulture and fr...   1412.0
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 2020-05-13                                                NaN   1507.0
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...      NaN
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 2020-12-08                                                NaN   1199.0
# ...

# %%
df11.interpolate(method='index')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description      Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...  1434.000000
# 2020-10-02  Farm expenses price index, Horticulture and fr...  1453.000000
# 2020-11-03  Farm expenses price index, Horticulture and fr...  1412.000000
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...  1489.000000
# 2020-05-13                                                NaN  1507.000000
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...  1347.507937
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...  1193.000000
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Revised')
df
# Out:
#         Series reference     Period  \
# Revised
# 1434          FPIQ.SEA31 2019-09-01
# 1453          FPIQ.SEA31 2019-12-01
# 1412          FPIQ.SEA31 2020-03-01
# 1489          FPIQ.SEB31 2019-09-01
# 1507          FPIQ.SEB31 2019-12-01
# 4500          FPIQ.SEB31 2020-03-01
# 1193                 NaN 2019-09-01
# 1199          FPIQ.SEB39 2019-12-01
# 1187          FPIQ.SEB39 2020-03-01
# 1159          FPIQ.SEB99 2019-12-01
#
#                                                Description  \
# Revised
# 1434     Farm expenses price index, Horticulture and fr...
# 1453     Farm expenses price index, Horticulture and fr...
# 1412     Farm expenses price index, Horticulture and fr...
# 1489     Farm expenses price index, Sheep, beef, and gr...
# 1507     Farm expenses price index, Sheep, beef, and gr...
# 4500     Farm expenses price index, Sheep, beef, and gr...
# 1193     Farm expenses price index, Sheep, beef, and gr...
# 1199     Farm expenses price index, Sheep, beef, and gr...
# ...

# %%
df.interpolate(method='index')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df

# %%
df
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Period')
df
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df

# %%
df.interpolate(method='index')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Revised')
df
# Out:
#         Series reference     Period  \
# Revised
# 1434          FPIQ.SEA31 2019-09-01
# 1453          FPIQ.SEA31 2019-12-01
# 1412          FPIQ.SEA31 2020-03-01
# 1489          FPIQ.SEB31 2019-09-01
# 1507          FPIQ.SEB31 2019-12-01
# 4500          FPIQ.SEB31 2020-03-01
# 1193                 NaN 2019-09-01
# 1199          FPIQ.SEB39 2019-12-01
# 1187          FPIQ.SEB39 2020-03-01
# 1159          FPIQ.SEB99 2019-12-01
#
#                                                Description  \
# Revised
# 1434     Farm expenses price index, Horticulture and fr...
# 1453     Farm expenses price index, Horticulture and fr...
# 1412     Farm expenses price index, Horticulture and fr...
# 1489     Farm expenses price index, Sheep, beef, and gr...
# 1507     Farm expenses price index, Sheep, beef, and gr...
# 4500     Farm expenses price index, Sheep, beef, and gr...
# 1193     Farm expenses price index, Sheep, beef, and gr...
# 1199     Farm expenses price index, Sheep, beef, and gr...
# ...

# %%
df.interpolate(method='index')
# Out:
#         Series reference     Period  \
# Revised
# 1434          FPIQ.SEA31 2019-09-01
# 1453          FPIQ.SEA31 2019-12-01
# 1412          FPIQ.SEA31 2020-03-01
# 1489          FPIQ.SEB31 2019-09-01
# 1507          FPIQ.SEB31 2019-12-01
# 4500          FPIQ.SEB31 2020-03-01
# 1193                 NaN 2019-09-01
# 1199          FPIQ.SEB39 2019-12-01
# 1187          FPIQ.SEB39 2020-03-01
# 1159          FPIQ.SEB99 2019-12-01
#
#                                                Description  \
# Revised
# 1434     Farm expenses price index, Horticulture and fr...
# 1453     Farm expenses price index, Horticulture and fr...
# 1412     Farm expenses price index, Horticulture and fr...
# 1489     Farm expenses price index, Sheep, beef, and gr...
# 1507     Farm expenses price index, Sheep, beef, and gr...
# 4500     Farm expenses price index, Sheep, beef, and gr...
# 1193     Farm expenses price index, Sheep, beef, and gr...
# 1199     Farm expenses price index, Sheep, beef, and gr...
# ...

# %%
df.interpolate(method="nearest")
# Out:
#         Series reference     Period  \
# Revised
# 1434          FPIQ.SEA31 2019-09-01
# 1453          FPIQ.SEA31 2019-12-01
# 1412          FPIQ.SEA31 2020-03-01
# 1489          FPIQ.SEB31 2019-09-01
# 1507          FPIQ.SEB31 2019-12-01
# 4500          FPIQ.SEB31 2020-03-01
# 1193                 NaN 2019-09-01
# 1199          FPIQ.SEB39 2019-12-01
# 1187          FPIQ.SEB39 2020-03-01
# 1159          FPIQ.SEB99 2019-12-01
#
#                                                Description  \
# Revised
# 1434     Farm expenses price index, Horticulture and fr...
# 1453     Farm expenses price index, Horticulture and fr...
# 1412     Farm expenses price index, Horticulture and fr...
# 1489     Farm expenses price index, Sheep, beef, and gr...
# 1507     Farm expenses price index, Sheep, beef, and gr...
# 4500     Farm expenses price index, Sheep, beef, and gr...
# 1193     Farm expenses price index, Sheep, beef, and gr...
# 1199     Farm expenses price index, Sheep, beef, and gr...
# ...

# %%
df11.interpolate(method='nearest')
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...   1434.0
# 2020-10-02  Farm expenses price index, Horticulture and fr...   1453.0
# 2020-11-03  Farm expenses price index, Horticulture and fr...   1412.0
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 2020-05-13                                                NaN   1507.0
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 2020-12-08                                                NaN   1199.0
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Period')
df
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv',parse_dates=['Period'],index_col='Period')
df

# %%
df.interpolate(method="polynomial",order=1)
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df.interpolate()
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2019-12-01       FPIQ.SEA31
# 2020-03-01       FPIQ.SEA31
# 2019-09-01       FPIQ.SEB31
# 2019-12-01       FPIQ.SEB31
# 2020-03-01       FPIQ.SEB31
# 2019-09-01              NaN
# 2019-12-01       FPIQ.SEB39
# 2020-03-01       FPIQ.SEB39
# 2019-12-01       FPIQ.SEB99
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...     1434
# 2019-12-01  Farm expenses price index, Horticulture and fr...     1453
# 2020-03-01  Farm expenses price index, Horticulture and fr...     1412
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1489
# 2019-12-01  Farm expenses price index, Sheep, beef, and gr...     1507
# 2020-03-01  Farm expenses price index, Sheep, beef, and gr...     4500
# 2019-09-01  Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df11.interpolate(method='polynomial',order=1)
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description      Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...  1434.000000
# 2020-10-02  Farm expenses price index, Horticulture and fr...  1453.000000
# 2020-11-03  Farm expenses price index, Horticulture and fr...  1412.000000
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...  1489.000000
# 2020-05-13                                                NaN  1507.000000
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...  1347.507937
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...  1193.000000
# ...

# %%
df11
# Out:
#            Series reference  \
# Period
# 2019-09-01       FPIQ.SEA31
# 2020-10-02       FPIQ.SEA31
# 2020-11-03       FPIQ.SEA31
# 2020-12-04       FPIQ.SEB31
# 2020-05-13       FPIQ.SEB31
# 2020-06-14              NaN
# 2020-07-15       FPIQ.SEB39
# 2020-12-08       FPIQ.SEB39
# 2020-12-09       FPIQ.SEB39
#
#                                                   Description  Revised  \
# Period
# 2019-09-01  Farm expenses price index, Horticulture and fr...   1434.0
# 2020-10-02  Farm expenses price index, Horticulture and fr...   1453.0
# 2020-11-03  Farm expenses price index, Horticulture and fr...   1412.0
# 2020-12-04  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 2020-05-13                                                NaN   1507.0
# 2020-06-14  Farm expenses price index, Sheep, beef, and gr...      NaN
# 2020-07-15  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 2020-12-08                                                NaN   1199.0
# ...
