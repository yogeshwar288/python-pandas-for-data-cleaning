# %% [markdown]
# # Python pandas tutorial-15

# %% [markdown]
# # pandas Groupby() function

# %%
import pandas as pd

# %%
df=pd.read_csv('G:\\csv\\household-living-costs-price-indexes-june-2020-quarter-group-facts.csv')
df
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# 5               Income quintile 4  2008  disq4   312336   229014  147658
# 6        Income quintile 5 (high)  2008  disq5   311574   253235  152835
# 7    Expenditure quintile 1 (low)  2008  expq1   312761   194358   49448
# 8          Expenditure quintile 2  2008  expq2   311973   206342   86390
# 9          Expenditure quintile 3  2008  expq3   311840   194361  108065
# 10         Expenditure quintile 4  2008  expq4   312257   231612  149007
# 11  Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %%
gr1=df.groupby(by='tot_hhs')
gr1

# %%
df11
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
gr1=df11.groupby(by='Revised')
gr1

# %%
df11
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free      0       Everyone
# ...

# %%
gr1=df11.groupby(['Rating','Installs']).groups
gr1
# Out:
# {(3.8, '50,000+'): [6], (3.9, '500,000+'): [1], (4.1, '1,000,000+'): [7], (4.1, '10,000+'): [0], (4.3, '100,000+'): [4], (4.4, '1,000,000+'): [8], (4.4, '50,000+'): [5], (4.5, '50,000,000+'): [3], (4.7, '10,000+'): [9], (4.7, '5,000,000+'): [2]}

# %%
gr1.groups
# Out:
# {185965: Int64Index([1], dtype='int64'),
#  253018: Int64Index([12], dtype='int64'),
#  300243: Int64Index([13], dtype='int64'),
#  311574: Int64Index([6], dtype='int64'),
#  311840: Int64Index([9], dtype='int64'),
#  311973: Int64Index([8], dtype='int64'),
#  312028: Int64Index([11], dtype='int64'),
#  312240: Int64Index([4], dtype='int64'),
#  312257: Int64Index([10], dtype='int64'),
#  312333: Int64Index([3], dtype='int64'),
#  312336: Int64Index([5], dtype='int64'),
#  312376: Int64Index([2], dtype='int64'),
#  312761: Int64Index([7], dtype='int64'),
#  1560859: Int64Index([0], dtype='int64'),
#  1607228: Int64Index([14], dtype='int64')}

# %%
gr1=df.groupby(['hlpi','tot_hhs']).groups
gr1
# Out:
# {('allhh', 1560859): Int64Index([0], dtype='int64'),
#  ('allhh', 1607228): Int64Index([14], dtype='int64'),
#  ('benef', 185965): Int64Index([1], dtype='int64'),
#  ('disq1', 312376): Int64Index([2], dtype='int64'),
#  ('disq2', 312333): Int64Index([3], dtype='int64'),
#  ('disq3', 312240): Int64Index([4], dtype='int64'),
#  ('disq4', 312336): Int64Index([5], dtype='int64'),
#  ('disq5', 311574): Int64Index([6], dtype='int64'),
#  ('expq1', 312761): Int64Index([7], dtype='int64'),
#  ('expq2', 311973): Int64Index([8], dtype='int64'),
#  ('expq3', 311840): Int64Index([9], dtype='int64'),
#  ('expq4', 312257): Int64Index([10], dtype='int64'),
#  ('expq5', 312028): Int64Index([11], dtype='int64'),
#  ('maori', 253018): Int64Index([12], dtype='int64'),
#  ('super', 300243): Int64Index([13], dtype='int64')}

# %%
for hlpi,df1 in gr1:
    print(hlpi)
    print(gr1)
# Out:
# allhh
# {('allhh', 1560859): Int64Index([0], dtype='int64'), ('allhh', 1607228): Int64Index([14], dtype='int64'), ('benef', 185965): Int64Index([1], dtype='int64'), ('disq1', 312376): Int64Index([2], dtype='int64'), ('disq2', 312333): Int64Index([3], dtype='int64'), ('disq3', 312240): Int64Index([4], dtype='int64'), ('disq4', 312336): Int64Index([5], dtype='int64'), ('disq5', 311574): Int64Index([6], dtype='int64'), ('expq1', 312761): Int64Index([7], dtype='int64'), ('expq2', 311973): Int64Index([8], dtype='int64'), ('expq3', 311840): Int64Index([9], dtype='int64'), ('expq4', 312257): Int64Index([10], dtype='int64'), ('expq5', 312028): Int64Index([11], dtype='int64'), ('maori', 253018): Int64Index([12], dtype='int64'), ('super', 300243): Int64Index([13], dtype='int64')}
# allhh
# ...

# %%
list(gr1)
# Out:
# [('allhh', 1560859),
#  ('allhh', 1607228),
#  ('benef', 185965),
#  ('disq1', 312376),
#  ('disq2', 312333),
#  ('disq3', 312240),
#  ('disq4', 312336),
#  ('disq5', 311574),
#  ('expq1', 312761),
#  ('expq2', 311973),
#  ('expq3', 311840),
#  ('expq4', 312257),
#  ('expq5', 312028),
#  ('maori', 253018),
#  ('super', 300243)]

# %%
dict(list(gr1))
# Out:
# {'allhh': 1607228,
#  'benef': 185965,
#  'disq1': 312376,
#  'disq2': 312333,
#  'disq3': 312240,
#  'disq4': 312336,
#  'disq5': 311574,
#  'expq1': 312761,
#  'expq2': 311973,
#  'expq3': 311840,
#  'expq4': 312257,
#  'expq5': 312028,
#  'maori': 253018,
#  'super': 300243}

# %%
gr3=df.groupby('year').get_group(2008)
gr3
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# 5               Income quintile 4  2008  disq4   312336   229014  147658
# 6        Income quintile 5 (high)  2008  disq5   311574   253235  152835
# 7    Expenditure quintile 1 (low)  2008  expq1   312761   194358   49448
# 8          Expenditure quintile 2  2008  expq2   311973   206342   86390
# 9          Expenditure quintile 3  2008  expq3   311840   194361  108065
# 10         Expenditure quintile 4  2008  expq4   312257   231612  149007
# 11  Expenditure quintile 5 (high)  2008  expq5   312028   260907  181496
# ...

# %%
gr3=df.groupby('prop_hhs').get_group(20)
gr3
# Out:
#                         hlpi_name  year   hlpi  tot_hhs     own  own_wm  \
# 2         Income quintile 1 (low)  2008  disq1   312376  191470   48424
# 3               Income quintile 2  2008  disq2   312333  196203   84171
# 4               Income quintile 3  2008  disq3   312240  217657  141318
# 5               Income quintile 4  2008  disq4   312336  229014  147658
# 6        Income quintile 5 (high)  2008  disq5   311574  253235  152835
# 7    Expenditure quintile 1 (low)  2008  expq1   312761  194358   49448
# 8          Expenditure quintile 2  2008  expq2   311973  206342   86390
# 9          Expenditure quintile 3  2008  expq3   311840  194361  108065
# 10         Expenditure quintile 4  2008  expq4   312257  231612  149007
# 11  Expenditure quintile 5 (high)  2008  expq5   312028  260907  181496
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# 2       61.3         15.5      20.0  40.0   2.3   16747        21145
# ...

# %%
gr3.sum()
# Out:
# hlpi_name      Income quintile 1 (low)Income quintile 2Income...
# year                                                       20080
# hlpi           disq1disq2disq3disq4disq5expq1expq2expq3expq4e...
# tot_hhs                                                  3121718
# own                                                      2175159
# own_wm                                                   1148812
# own_prop                                                   696.7
# own_wm_prop                                                368.2
# prop_hhs                                                     200
# age                                                        360.4
# size                                                        26.4
# income                                                    501599
# expenditure                                               459387
# eqv_income                                                295083
# ...

# %%
gr3.mean()
# Out:
# year             2008.00
# tot_hhs        312171.80
# own            217515.90
# own_wm         114881.20
# own_prop           69.67
# own_wm_prop        36.82
# prop_hhs           20.00
# age                36.04
# size                2.64
# income          50159.90
# expenditure     45938.70
# eqv_income      29508.30
# eqv_exp         27222.10
# dtype: float64

# %%
gr3.describe()
# Out:
#          year        tot_hhs            own         own_wm   own_prop  \
# count    10.0      10.000000      10.000000      10.000000  10.000000
# mean   2008.0  312171.800000  217515.900000  114881.200000  69.670000
# std       0.0     330.213332   25428.527927   46326.383519   8.196347
# min    2008.0  311574.000000  191470.000000   48424.000000  61.300000
# 25%    2008.0  311986.750000  194821.500000   84725.750000  62.425000
# 50%    2008.0  312248.500000  211999.500000  124691.500000  67.900000
# 75%    2008.0  312335.250000  230962.500000  148669.750000  73.975000
# max    2008.0  312761.000000  260907.000000  181496.000000  83.600000
#
#        own_wm_prop  prop_hhs        age       size        income  \
# count    10.000000      10.0  10.000000  10.000000     10.000000
# mean     36.820000      20.0  36.040000   2.640000  50159.900000
# std      14.871584       0.0   2.726496   0.201108  24949.771802
# min      15.500000      20.0  31.500000   2.300000  16747.000000
# ...

# %%
gr3.agg(['sum','max','mean'])
# Out:
#                                               hlpi_name     year  \
# sum   Income quintile 1 (low)Income quintile 2Income...  20080.0
# max                            Income quintile 5 (high)   2008.0
# mean                                                NaN   2008.0
#
#                                                    hlpi    tot_hhs        own  \
# sum   disq1disq2disq3disq4disq5expq1expq2expq3expq4e...  3121718.0  2175159.0
# max                                               expq5   312761.0   260907.0
# mean                                                NaN   312171.8   217515.9
#
#          own_wm  own_prop  own_wm_prop  prop_hhs     age   size    income  \
# sum   1148812.0    696.70       368.20     200.0  360.40  26.40  501599.0
# max    181496.0     83.60        58.20      20.0   40.00   3.00   96861.0
# mean   114881.2     69.67        36.82      20.0   36.04   2.64   50159.9
#
#       expenditure  eqv_income   eqv_exp
# sum      459387.0    295083.0  272221.0
# ...

# %%
df11=pd.read_csv('E:\csv files\googleplaystore.csv',nrows=10)
df11
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free      0       Everyone
# ...

# %%
df11
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free      0       Everyone
# ...
