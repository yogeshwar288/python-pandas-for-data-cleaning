# %% [markdown]
# # python pandas tutorial-13

# %% [markdown]
# # pandas interpolate()

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv')
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df1=pd.read_csv('E:\csv files\ppppppppppppppppp.csv')
df1
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df1.interpolate(limit=1)
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1350.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df.interpolate(limit=1)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df.interpolate(limit=2)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df1
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df1.interpolate(limit=1,limit_direction='forward')
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1350.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df1.interpolate(limit=1,limit_direction='backward')
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1350.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df.interpolate(limit=1,limit_direction="backward")
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df1.interpolate(limit=1,limit_area='inside')
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...   1350.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df.interpolate(limit=1,limit_area="inside")
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df.interpolate(limit=4,limit_area="inside")
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df.interpolate(limit_area="inside")
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df1.interpolate(limit=1,limit_area='outside')
# Out:
#   Series reference     Period  \
# 0       FPIQ.SEA31   9/1/2019
# 1       FPIQ.SEA31  10/2/2020
# 2       FPIQ.SEA31  11/3/2020
# 3       FPIQ.SEB31  12/4/2020
# 4       FPIQ.SEB31  13/5/2020
# 5              NaN  14/6/2020
# 6       FPIQ.SEB39  15/7/2020
# 7       FPIQ.SEB39  12/8/2020
# 8       FPIQ.SEB39  12/9/2020
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4                                                NaN   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7                                                NaN   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# ...

# %%
df.interpolate(limit_area="outside")
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df.interpolate(inplace=True)
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...     1434
# 1  Farm expenses price index, Horticulture and fr...     1453
# 2  Farm expenses price index, Horticulture and fr...     1412
# 3  Farm expenses price index, Sheep, beef, and gr...     1489
# 4  Farm expenses price index, Sheep, beef, and gr...     1507
# 5  Farm expenses price index, Sheep, beef, and gr...     4500
# 6  Farm expenses price index, Sheep, beef, and gr...     1193
# 7  Farm expenses price index, Sheep, beef, and gr...     1199
# 8  Farm expenses price index, Sheep, beef, and gr...     1187
# ...
