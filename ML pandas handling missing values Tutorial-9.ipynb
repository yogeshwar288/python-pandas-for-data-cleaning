# %% [markdown]
# # python pandas tutorial-9

# %% [markdown]
# # pandas handling missing values in python-3

# %%
import pandas as pd

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv')
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.dropna(1)#axis 1= column drop
# Out:
#     1   Eldon Base for stackable storage shelf, platinum    3   38.94     35  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...  293  208.16  68.02
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl  293    8.69   2.99
# 2   4                                               R380  483  195.99   3.99
# 3   5                           Holmes HEPA Air Purifier  515   21.78   5.94
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs  515    6.64   4.95
# 5   7  Angle-D Binders with Locking Rings, Label Holders  613    7.30   7.72
# 6   8            SAFCO Mobile Desk Side File, Wire Frame  613   42.76   6.22
# 7   9              SAFCO Commercial Wire Shelving, Black  643  138.14  35.00
# 8  10                                          Xerox 198  678    4.98   8.33
#
#            Storage & Organization
# 0                      Appliances
# 1  Binders and Binder Accessories
# 2    Telephones and Communication
# 3                      Appliances
# ...

# %%
df11.dropna()
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 8  678  -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df.dropna()
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 4       FPIQ.SEB31  2019.12
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# 0               1453.0
# 1               1472.0
# 2               1431.0
# 4               1510.0
# 7               1200.0
# 8               1188.0

# %%
df.dropna(1)
# Out:
#     Period                                        Description
# 0  2019.09  Farm expenses price index, Horticulture and fr...
# 1  2019.12  Farm expenses price index, Horticulture and fr...
# 2  2020.03  Farm expenses price index, Horticulture and fr...
# 3  2019.09  Farm expenses price index, Sheep, beef, and gr...
# 4  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 5  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 6  2019.09  Farm expenses price index, Sheep, beef, and gr...
# 7  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 8  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 9  2019.12  Farm expenses price index, Sheep, beef, and gr...

# %%
df.dropna(0)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 4       FPIQ.SEB31  2019.12
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# 0               1453.0
# 1               1472.0
# 2               1431.0
# 4               1510.0
# 7               1200.0
# 8               1188.0

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.dropna(how='all')
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.dropna(how='any')
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 8  678  -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df11.dropna(axis=1,how='any')
# Out:
#     1   Eldon Base for stackable storage shelf, platinum    3   38.94     35  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...  293  208.16  68.02
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl  293    8.69   2.99
# 2   4                                               R380  483  195.99   3.99
# 3   5                           Holmes HEPA Air Purifier  515   21.78   5.94
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs  515    6.64   4.95
# 5   7  Angle-D Binders with Locking Rings, Label Holders  613    7.30   7.72
# 6   8            SAFCO Mobile Desk Side File, Wire Frame  613   42.76   6.22
# 7   9              SAFCO Commercial Wire Shelving, Black  643  138.14  35.00
# 8  10                                          Xerox 198  678    4.98   8.33
#
#            Storage & Organization
# 0                      Appliances
# 1  Binders and Binder Accessories
# 2    Telephones and Communication
# 3                      Appliances
# ...

# %%
df.dropna(how='any')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 4       FPIQ.SEB31  2019.12
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# 0               1453.0
# 1               1472.0
# 2               1431.0
# 4               1510.0
# 7               1200.0
# 8               1188.0

# %%
df.dropna(axis=1,how='any')
# Out:
#     Period                                        Description
# 0  2019.09  Farm expenses price index, Horticulture and fr...
# 1  2019.12  Farm expenses price index, Horticulture and fr...
# 2  2020.03  Farm expenses price index, Horticulture and fr...
# 3  2019.09  Farm expenses price index, Sheep, beef, and gr...
# 4  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 5  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 6  2019.09  Farm expenses price index, Sheep, beef, and gr...
# 7  2019.12  Farm expenses price index, Sheep, beef, and gr...
# 8  2020.03  Farm expenses price index, Sheep, beef, and gr...
# 9  2019.12  Farm expenses price index, Sheep, beef, and gr...

# %%
df.dropna(axis=0,how='all')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.dropna(axis=0,how='all')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv')
df1
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df1.dropna(axis=0,how='all')
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.dropna(thresh=1)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
df11.dropna(thresh=10)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 8  678  -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df.dropna(thresh=2)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.dropna(thresh=3)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
df.dropna(thresh=5)
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 4       FPIQ.SEB31  2019.12
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# 0               1453.0
# 1               1472.0
# 2               1431.0
# 4               1510.0
# 7               1200.0
# 8               1188.0

# %%
df1=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-missing value file.csv')
df1
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# ...

# %%
#subset parameter

# %%
df.dropna(subset=['Revised'])
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 6              NaN  2019.09
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 6  Farm expenses price index, Sheep, beef, and gr...   1193.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# 9  Farm expenses price index, Sheep, beef, and gr...   1159.0
#
#    Initially published
# 0               1453.0
# ...

# %%
df.dropna(subset=['Series reference'])
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 3       FPIQ.SEB31  2019.09
# 4       FPIQ.SEB31  2019.12
# 5       FPIQ.SEB31  2020.03
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
# 9       FPIQ.SEB99  2019.12
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 3  Farm expenses price index, Sheep, beef, and gr...   1489.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5  Farm expenses price index, Sheep, beef, and gr...      NaN
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
# 9  Farm expenses price index, Sheep, beef, and gr...   1159.0
#
#    Initially published
# 0               1453.0
# ...

# %%
df1.dropna(inplace=True)

# %%
df1.dropna(inplace=True)
df1
# Out:
#   Series reference   Period  \
# 0       FPIQ.SEA31  2019.09
# 1       FPIQ.SEA31  2019.12
# 2       FPIQ.SEA31  2020.03
# 4       FPIQ.SEB31  2019.12
# 7       FPIQ.SEB39  2019.12
# 8       FPIQ.SEB39  2020.03
#
#                                          Description  Revised  \
# 0  Farm expenses price index, Horticulture and fr...   1434.0
# 1  Farm expenses price index, Horticulture and fr...   1453.0
# 2  Farm expenses price index, Horticulture and fr...   1412.0
# 4  Farm expenses price index, Sheep, beef, and gr...   1507.0
# 7  Farm expenses price index, Sheep, beef, and gr...   1199.0
# 8  Farm expenses price index, Sheep, beef, and gr...   1187.0
#
#    Initially published
# 0               1453.0
# 1               1472.0
# 2               1431.0
# 4               1510.0
# 7               1200.0
# 8               1188.0

# %%
df11.dropna()
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 8  678  -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.dropna(subset=['0.8'])
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# ...

# %%
df11.dropna(subset=['Muhammed MacIntyre'])
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# ...

# %%
df11.dropna(inplace=True)

# %%
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 8  678  -226.36    4.98   8.33  Nunavut                           Paper  0.38
