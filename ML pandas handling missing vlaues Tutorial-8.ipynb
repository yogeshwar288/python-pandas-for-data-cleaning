# %% [markdown]
# # python pandas Tutorial-8

# %% [markdown]
# # handling missing values in python-2

# %%
import pandas as pd

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6        FPIQ.SEB39  2019.09
# 7        FPIQ.SEB39  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...     1434
# 1   Farm expenses price index, Horticulture and fr...     1453
# 2   Farm expenses price index, Horticulture and fr...     1412
# 3   Farm expenses price index, Sheep, beef, and gr...     1489
# 4   Farm expenses price index, Sheep, beef, and gr...     1507
# 5   Farm expenses price index, Sheep, beef, and gr...     1462
# 6   Farm expenses price index, Sheep, beef, and gr...     1193
# ...

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
#if we want to know how many null or null values here in our data set or data frame  for we using isnull() function

# %%
df.isnull()
# Out:
#     Series reference  Period  Description  Revised  Initially published
# 0              False   False        False    False                False
# 1              False   False        False    False                False
# 2              False   False        False    False                False
# 3              False   False        False    False                False
# 4              False   False        False    False                False
# 5              False   False        False    False                False
# 6              False   False        False    False                False
# 7              False   False        False    False                False
# 8              False   False        False    False                False
# 9              False   False        False    False                False
# 10             False   False        False    False                False
# 11             False   False        False    False                False
# ...

# %%
df11.isnull()
# Out:
#        1  Eldon Base for stackable storage shelf, platinum  \
# 0  False                                             False
# 1  False                                             False
# 2  False                                             False
# 3  False                                             False
# 4  False                                             False
# 5  False                                             False
# 6  False                                             False
# 7  False                                             False
# 8  False                                             False
#
#    Muhammed MacIntyre      3  -213.25  38.94     35  Nunavut  \
# 0               False  False    False  False  False    False
# 1               False  False    False  False  False    False
# 2                True  False    False  False  False    False
# 3               False  False    False  False  False    False
# 4                True  False    False  False  False    False
# ...

# %%
#false mean hmare data set me koi missing value nhi hai

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6               NaN  2019.09
# 7               NaN  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...   1434.0
# 1   Farm expenses price index, Horticulture and fr...   1453.0
# 2   Farm expenses price index, Horticulture and fr...      NaN
# 3   Farm expenses price index, Sheep, beef, and gr...      NaN
# 4   Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5   Farm expenses price index, Sheep, beef, and gr...   1462.0
# 6   Farm expenses price index, Sheep, beef, and gr...   1193.0
# ...

# %%
df.isnull()
# Out:
#     Series reference  Period  Description  Revised  Initially published
# 0              False   False        False    False                False
# 1              False   False        False    False                False
# 2              False   False        False     True                False
# 3              False   False        False     True                False
# 4              False   False        False    False                False
# 5              False   False        False    False                False
# 6               True   False        False    False                False
# 7               True   False        False    False                False
# 8              False   False        False    False                False
# 9              False   False        False    False                 True
# 10             False   False        False    False                 True
# 11             False   False        False    False                False
# ...

# %%
#missing valur=true

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.isnull().sum()
# Out:
# 1                                                   0
# Eldon Base for stackable storage shelf, platinum    0
# Muhammed MacIntyre                                  2
# 3                                                   0
# -213.25                                             2
# 38.94                                               0
# 35                                                  0
# Nunavut                                             1
# Storage & Organization                              0
# 0.8                                                 2
# dtype: int64

# %%
df11.isnull().sum().sum()
# Out:
# 7

# %%
#total missing value column wise
df.isnull().sum()
# Out:
# Series reference       2
# Period                 0
# Description            0
# Revised                2
# Initially published    2
# dtype: int64

# %%
#for all missing value count
df.isnull().sum().sum()
# Out:
# 6

# %%
df=pd.read_csv('G:\\csv\\business-price-indexes-june-2020-quarter-corrections-to-previously-published-statistics.csv')
df
# Out:
#    Series reference   Period  \
# 0        FPIQ.SEA31  2019.09
# 1        FPIQ.SEA31  2019.12
# 2        FPIQ.SEA31  2020.03
# 3        FPIQ.SEB31  2019.09
# 4        FPIQ.SEB31  2019.12
# 5        FPIQ.SEB31  2020.03
# 6               NaN  2019.09
# 7               NaN  2019.12
# 8        FPIQ.SEB39  2020.03
# 9        FPIQ.SEB99  2019.12
# 10       FPIQ.SEC31  2019.09
# 11       FPIQ.SEC31  2019.12
# 12       FPIQ.SEC31  2020.03
# 13       FPIQ.SEC39  2019.09
#
#                                           Description  Revised  \
# 0   Farm expenses price index, Horticulture and fr...   1434.0
# 1   Farm expenses price index, Horticulture and fr...   1453.0
# 2   Farm expenses price index, Horticulture and fr...      NaN
# 3   Farm expenses price index, Sheep, beef, and gr...      NaN
# 4   Farm expenses price index, Sheep, beef, and gr...   1507.0
# 5   Farm expenses price index, Sheep, beef, and gr...   1462.0
# 6   Farm expenses price index, Sheep, beef, and gr...   1193.0
# ...

# %%
df11=pd.read_csv('E:\csv files\SampleCSVfile.csv')
df11
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380                NaN
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs                NaN
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df11.notnull()
# Out:
#       1  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre  \
# 0  True                                              True                True
# 1  True                                              True                True
# 2  True                                              True               False
# 3  True                                              True                True
# 4  True                                              True               False
# 5  True                                              True                True
# 6  True                                              True                True
# 7  True                                              True                True
# 8  True                                              True                True
#
#       3  -213.25  38.94    35  Nunavut  Storage & Organization    0.8
# 0  True     True   True  True     True                    True   True
# ...

# %%
df11.notnull().sum()
# Out:
# 1                                                   9
# Eldon Base for stackable storage shelf, platinum    9
# Muhammed MacIntyre                                  7
# 3                                                   9
# -213.25                                             7
# 38.94                                               9
# 35                                                  9
# Nunavut                                             8
# Storage & Organization                              9
# 0.8                                                 7
# dtype: int64

# %%
df11.notnull().sum().sum()
# Out:
# 83

# %%
#notnull() ye function ulta opposite hota hai isnulla() function ke
df.notnull()
# Out:
#     Series reference  Period  Description  Revised  Initially published
# 0               True    True         True     True                 True
# 1               True    True         True     True                 True
# 2               True    True         True    False                 True
# 3               True    True         True    False                 True
# 4               True    True         True     True                 True
# 5               True    True         True     True                 True
# 6              False    True         True     True                 True
# 7              False    True         True     True                 True
# 8               True    True         True     True                 True
# 9               True    True         True     True                False
# 10              True    True         True     True                False
# 11              True    True         True     True                 True
# ...

# %%
#missing value = false, unmissing value= true
df.notnull().sum()
# Out:
# Series reference       12
# Period                 14
# Description            14
# Revised                12
# Initially published    12
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 64

# %% [markdown]
# # series for isnull() and notnull()

# %%
import numpy as np

# %%
sr=pd.Series([1,2,3,np.NaN,4,np.NaN,5,])
sr
#np.NaN  missing value ke rup me use kiya gya hai
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# 6    5.0
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
sr.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# dtype: bool

# %%
sr.notnull().sum()
# Out:
# 5
